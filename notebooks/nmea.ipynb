# %%
from utils.nmea.parse import parse_nmea_file

parse_nmea_file('data/TrimbleR1_20160310-165531.txt')
# Out:
# [GGAMessage(date=datetime.datetime(2025, 5, 6, 22, 56, 51), latitude=np.float64(0.6334269058487977), longitude=np.float64(-1.6983524566490673), fix_quality=1, number_of_satellites=3, horizontal_dilution=4.4, altitude=322.48, altitude_units='M', geoidal_separation=-25.964, geoidal_separation_units='M', age_of_diff_corr='', diff_ref_station_id=''),
#  GGAMessage(date=datetime.datetime(2025, 5, 6, 22, 56, 52), latitude=np.float64(0.6334269056044516), longitude=np.float64(-1.6983524550695446), fix_quality=1, number_of_satellites=3, horizontal_dilution=4.4, altitude=322.48, altitude_units='M', geoidal_separation=-25.964, geoidal_separation_units='M', age_of_diff_corr='', diff_ref_station_id=''),
# ...
